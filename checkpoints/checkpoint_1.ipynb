# %% [markdown]
# #### Checkpoint #1

# %%
# Out:
# /Users/jackgibson/Documents/30254-ml/silent_p/checkpoints

# %%
import pandas as pd

train = pd.read_csv('/Users/jackgibson/Documents/30254-ml/silent_p/data/output/train.csv')

# %%
train.hist(column='width')
# Out:
# array([[<AxesSubplot:title={'center':'width'}>]], dtype=object)

# %%
train.hist(column='height')
train['height'].describe()
# Out:
# count    5216.000000
# mean      968.074770
# std       378.855691
# min       127.000000
# 25%       688.000000
# 50%       888.000000
# 75%      1187.750000
# max      2663.000000
# Name: height, dtype: float64
